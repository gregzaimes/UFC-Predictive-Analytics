# %%
#Load python packages
import pandas as pd
import numpy as np

#Import UFC Fight data, create new variables (columns)
odds_data = pd.read_csv('UFC Odds.csv', engine = "python")
df = pd.read_csv('UFC Fight Data.csv')
df["Body_Attempt"] = df["B_avg_BODY_att"]/df["R_avg_BODY_att"]
df["Body_Landed"]=df["B_avg_BODY_landed"]/df["R_avg_BODY_landed"]
df["Clinch_Attempt"]=df["B_avg_CLINCH_att"]/df["R_avg_CLINCH_att"]
df["Clinch_Land"]=df["B_avg_CLINCH_landed"]/df["R_avg_CLINCH_landed"]
df["Distance_Attempt"]=df["B_avg_DISTANCE_att"]/df["R_avg_DISTANCE_att"]
df["Distance_Landed"]=df["B_avg_DISTANCE_landed"]/df["R_avg_DISTANCE_landed"]
df["Ground_Attempt"]=df["B_avg_GROUND_att"]/df["R_avg_GROUND_att"]
df["Ground_Landed"]=df["B_avg_GROUND_landed"]/df["R_avg_GROUND_landed"]
df["Head_Attempt"]=df["B_avg_HEAD_att"]/df["R_avg_HEAD_att"]
df["Head_Landed"]=df["B_avg_HEAD_landed"]/df["R_avg_HEAD_landed"]
df["KD_avg"]=df["B_avg_KD"]/df["R_avg_KD"]
df["Leg_Attempt"]=df["B_avg_LEG_att"]/df["R_avg_LEG_att"]
df["Leg_Landed"]=df["B_avg_LEG_landed"]/df["R_avg_LEG_landed"]
df["Pass_Avg"]=df["B_avg_PASS"]/df["R_avg_PASS"]
df["Rev_Avg"]=df["B_avg_REV"]/df["R_avg_PASS"]
df["Sig_Str_Att"]=df["B_avg_SIG_STR_att"]/df["R_avg_SIG_STR_att"]
df["Sig_Str_Landed"]=df["B_avg_SIG_STR_landed"]/df["R_avg_SIG_STR_landed"]
df["Sig_Str_Pct"]=df["B_avg_SIG_STR_pct"]/df["R_avg_SIG_STR_pct"]
df["Sub_Att"]=df["B_avg_SUB_ATT"]/df["R_avg_SUB_ATT"]
df["TD_Att"]=df["B_avg_TD_att"]/df["R_avg_TD_att"]
df["TD_Landed"]=df["B_avg_TD_landed"]/df["R_avg_TD_landed"]
df["TD_Pct"]=df["B_avg_TD_pct"]/df["R_avg_TD_pct"]
df["Total_Str_Att"]=df["B_avg_TOTAL_STR_att"]/df["R_avg_TOTAL_STR_att"]
df["Total_Str_Landed"]=df["B_avg_TOTAL_STR_landed"]/df["R_avg_TOTAL_STR_landed"]

# Merge UFC Fighting and Odds Dataset
df = df.merge(odds_data, left_on = ["R_fighter", "B_fighter",'date','weight_class'], right_on = ["R_fighter", "B_fighter",'date','weight_class'], how = "left")



## Oddds should be converted to percentages rather than +/- moneline odds.This may need a for loop to convert between moneyline
## odds and percentage, since it is different for +/- values
##Implied probability	=	( - ( 'minus' moneyline odds ) ) / ( - ( 'minus' moneyline odds ) ) + 100
##Implied probability	=	100 / ( 'plus' moneyline odds + 100 )

#df["Rodds_percent"] = 

#for i in df[""]

# %%
df = df.replace([np.inf, -np.inf], np.nan)
#df = df.fillna(0)

# %%
# Create new Year variable 
df['Year'] = df['date'].astype(str)
df['Year'] = df['Year'].str[-2:]

# %%
df
# Out:
#                   R_fighter            B_fighter               Referee  \
# 0              Henry Cejudo        Marlon Moraes          Marc Goddard
# 1      Valentina Shevchenko          Jessica Eye       Robert Madrigal
# 2             Tony Ferguson       Donald Cerrone       Dan Miragliotta
# 3             Jimmie Rivera             Petr Yan       Kevin MacDonald
# 4               Tai Tuivasa        Blagoy Ivanov       Dan Miragliotta
# 5            Tatiana Suarez        Nina Ansaroff       Robert Madrigal
# 6         Aljamain Sterling         Pedro Munhoz          Marc Goddard
# 7     Karolina Kowalkiewicz         Alexa Grasso       Kevin MacDonald
# 8             Ricardo Lamas        Calvin Kattar       Dan Miragliotta
# 9               Yan Xiaonan          Angela Hill       Robert Madrigal
# 10              Bevon Lewis       Darren Stewart          Marc Goddard
# 11           Eddie Wineland       Grigorii Popov       Kevin MacDonald
# 12        Katlyn Chookagian    Joanne Calderwood       Dan Miragliotta
# 13     Alexander Gustafsson        Anthony Smith          Marc Goddard
# 14              Jimi Manuwa     Aleksandar Rakic          Kevin Sataki
# 15         Makwan Amirkhani       Chris Fishgold          Marc Goddard
# 16           Damir Hadzovic      Christos Giagos         Rich Mitchell
# 17            Daniel Teymur          Sung Bin Jo           Rebin Saber
# 18             Rostem Akman    Sergey Khandozhko          Leon Roberts
# 19            Tonya Evinger        Lina Lansberg          Kevin Sataki
# 20               Stevie Ray      Leonardo Santos          Marc Goddard
# 21                Nick Hein        Frank Camacho          Leon Roberts
# 22              Bea Malecki         Duda Santana                   NaN
# 23             Darko Stosic          Devin Clark          Kevin Sataki
# 24             Joel Alvarez     Danilo Belluardo           Rebin Saber
# 25         Rafael Dos Anjos            Kevin Lee       Dan Miragliotta
# 26    Antonio Carlos Junior         Ian Heinisch  Todd Ronald Anderson
# 27           Megan Anderson      Felicia Spencer        Keith Peterson
# 28            Vicente Luque       Derrick Krantz       Dan Miragliotta
# 29         Charles Oliveira            Nik Lentz  Todd Ronald Anderson
# ...                     ...                  ...                   ...
# 5114             Guy Mezger          Jason Fairn         John McCarthy
# 5115           Steve Jennum        Harold Howard         John McCarthy
# 5116           Ken Shamrock   Felix Lee Mitchell         John McCarthy
# 5117           Royce Gracie        Kimo Leopoldo         John McCarthy
# 5118          Harold Howard         Roland Payne         John McCarthy
# 5119           Ken Shamrock  Christophe Leninger         John McCarthy
# 5120          Keith Hackney  Emmanuel Yarborough         John McCarthy
# 5121           Royce Gracie        Patrick Smith         John McCarthy
# 5122           Royce Gracie        Remco Pardoel         John McCarthy
# 5123          Patrick Smith        Johnny Rhodes         John McCarthy
# 5124           Royce Gracie        Jason DeLucia         John McCarthy
# 5125          Remco Pardoel         Orlando Wiet         John McCarthy
# 5126          Johnny Rhodes          Fred Ettish         John McCarthy
# 5127          Patrick Smith         Scott Morris         John McCarthy
# 5128           Royce Gracie      Minoki Ichihara         John McCarthy
# 5129          Jason DeLucia          Scott Baker         John McCarthy
# 5130          Remco Pardoel   Alberta Cerra Leon         John McCarthy
# 5131           Orlando Wiet     Robert Lucarelli         John McCarthy
# 5132          Frank Hamaker      Thaddeus Luster         John McCarthy
# 5133          Johnny Rhodes        David Levicki         John McCarthy
# 5134          Patrick Smith           Ray Wizard         John McCarthy
# 5135           Scott Morris       Sean Daugherty         John McCarthy
# 5136           Royce Gracie       Gerard Gordeau  Joao Alberto Barreto
# 5137          Jason DeLucia        Trent Jenkins  Joao Alberto Barreto
# 5138           Royce Gracie         Ken Shamrock  Joao Alberto Barreto
# 5139         Gerard Gordeau         Kevin Rosier  Joao Alberto Barreto
# 5140           Ken Shamrock        Patrick Smith  Joao Alberto Barreto
# 5141           Royce Gracie        Art Jimmerson  Joao Alberto Barreto
# 5142           Kevin Rosier         Zane Frazier  Joao Alberto Barreto
# 5143         Gerard Gordeau           Teila Tuli  Joao Alberto Barreto
#
#           date                      location_x Winner_x  WinnerNum  \
# 0       6/8/19          Chicago, Illinois, USA      Red          1
# 1       6/8/19          Chicago, Illinois, USA      Red          1
# 2       6/8/19          Chicago, Illinois, USA      Red          1
# 3       6/8/19          Chicago, Illinois, USA     Blue          0
# 4       6/8/19          Chicago, Illinois, USA     Blue          0
# 5       6/8/19          Chicago, Illinois, USA      Red          1
# 6       6/8/19          Chicago, Illinois, USA      Red          1
# 7       6/8/19          Chicago, Illinois, USA     Blue          0
# 8       6/8/19          Chicago, Illinois, USA     Blue          0
# 9       6/8/19          Chicago, Illinois, USA      Red          1
# 10      6/8/19          Chicago, Illinois, USA     Blue          0
# 11      6/8/19          Chicago, Illinois, USA      Red          1
# 12      6/8/19          Chicago, Illinois, USA      Red          1
# 13      6/1/19               Stockholm, Sweden     Blue          0
# 14      6/1/19               Stockholm, Sweden     Blue          0
# 15      6/1/19               Stockholm, Sweden      Red          1
# 16      6/1/19               Stockholm, Sweden     Blue          0
# 17      6/1/19               Stockholm, Sweden      Red          1
# 18      6/1/19               Stockholm, Sweden     Blue          0
# 19      6/1/19               Stockholm, Sweden     Blue          0
# 20      6/1/19               Stockholm, Sweden     Blue          0
# 21      6/1/19               Stockholm, Sweden     Blue          0
# 22      6/1/19               Stockholm, Sweden      Red          1
# 23      6/1/19               Stockholm, Sweden     Blue          0
# 24      6/1/19               Stockholm, Sweden      Red          1
# 25     5/18/19        Rochester, New York, USA      Red          1
# 26     5/18/19        Rochester, New York, USA     Blue          0
# 27     5/18/19        Rochester, New York, USA     Blue          0
# 28     5/18/19        Rochester, New York, USA      Red          1
# 29     5/18/19        Rochester, New York, USA      Red          1
# ...        ...                             ...      ...        ...
# 5114  12/16/94            Tulsa, Oklahoma, USA      Red          1
# 5115    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5116    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5117    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5118    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5119    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5120    9/9/94  Charlotte, North Carolina, USA      Red          1
# 5121   3/11/94           Denver, Colorado, USA      Red          1
# 5122   3/11/94           Denver, Colorado, USA      Red          1
# 5123   3/11/94           Denver, Colorado, USA      Red          1
# 5124   3/11/94           Denver, Colorado, USA      Red          1
# 5125   3/11/94           Denver, Colorado, USA      Red          1
# 5126   3/11/94           Denver, Colorado, USA      Red          1
# 5127   3/11/94           Denver, Colorado, USA      Red          1
# 5128   3/11/94           Denver, Colorado, USA      Red          1
# 5129   3/11/94           Denver, Colorado, USA      Red          1
# 5130   3/11/94           Denver, Colorado, USA      Red          1
# 5131   3/11/94           Denver, Colorado, USA      Red          1
# 5132   3/11/94           Denver, Colorado, USA      Red          1
# 5133   3/11/94           Denver, Colorado, USA      Red          1
# 5134   3/11/94           Denver, Colorado, USA      Red          1
# 5135   3/11/94           Denver, Colorado, USA      Red          1
# 5136  11/12/93           Denver, Colorado, USA      Red          1
# 5137  11/12/93           Denver, Colorado, USA      Red          1
# 5138  11/12/93           Denver, Colorado, USA      Red          1
# 5139  11/12/93           Denver, Colorado, USA      Red          1
# 5140  11/12/93           Denver, Colorado, USA      Red          1
# 5141  11/12/93           Denver, Colorado, USA      Red          1
# 5142  11/12/93           Denver, Colorado, USA      Red          1
# 5143  11/12/93           Denver, Colorado, USA      Red          1
#
#       title_bout_x           weight_class  no_of_rounds  ...  Total_Str_Att  \
# 0             True           Bantamweight             5  ...       0.511162
# 1             True      Women's Flyweight             5  ...       0.982228
# 2            False            Lightweight             3  ...       0.779772
# 3            False           Bantamweight             3  ...       1.318424
# 4            False            Heavyweight             3  ...       3.212598
# 5            False    Women's Strawweight             3  ...       1.807882
# 6            False           Bantamweight             3  ...       0.742169
# 7            False    Women's Strawweight             3  ...       0.783535
# 8            False          Featherweight             3  ...       1.740625
# 9            False    Women's Strawweight             3  ...       0.609974
# 10           False           Middleweight             3  ...       0.387755
# 11           False           Bantamweight             3  ...            NaN
# 12           False      Women's Flyweight             3  ...       0.771395
# 13           False      Light Heavyweight             5  ...       0.551915
# 14           False      Light Heavyweight             3  ...       3.397611
# 15           False          Featherweight             3  ...       1.313364
# 16           False            Lightweight             3  ...       0.873563
# 17           False          Featherweight             3  ...            NaN
# 18           False           Welterweight             3  ...            NaN
# 19           False   Women's Bantamweight             3  ...       1.849541
# 20           False            Lightweight             3  ...       0.722930
# 21           False            Lightweight             3  ...       2.024553
# 22           False   Women's Bantamweight             3  ...            NaN
# 23           False      Light Heavyweight             3  ...       7.019608
# 24           False            Lightweight             3  ...            NaN
# 25           False           Welterweight             5  ...       1.099080
# 26           False           Middleweight             3  ...       1.797297
# 27           False  Women's Featherweight             3  ...            NaN
# 28           False           Welterweight             3  ...            NaN
# 29           False            Lightweight             3  ...       2.397484
# ...            ...                    ...           ...  ...            ...
# 5114         False            Open Weight             1  ...            NaN
# 5115          True           Catch Weight             1  ...            NaN
# 5116         False            Open Weight             1  ...            NaN
# 5117         False            Open Weight             1  ...            NaN
# 5118         False            Open Weight             1  ...            NaN
# 5119         False            Open Weight             1  ...            NaN
# 5120         False            Open Weight             1  ...            NaN
# 5121          True           Catch Weight             1  ...       0.635036
# 5122         False            Open Weight             1  ...       0.529197
# 5123         False            Open Weight             1  ...       4.043478
# 5124         False            Open Weight             1  ...       0.496350
# 5125         False            Open Weight             1  ...       0.681818
# 5126         False            Open Weight             1  ...            NaN
# 5127         False            Open Weight             1  ...       0.190476
# 5128         False            Open Weight             1  ...            NaN
# 5129         False            Open Weight             1  ...            NaN
# 5130         False            Open Weight             1  ...            NaN
# 5131         False            Open Weight             1  ...            NaN
# 5132         False            Open Weight             1  ...            NaN
# 5133         False            Open Weight             1  ...            NaN
# 5134         False            Open Weight             1  ...            NaN
# 5135         False            Open Weight             1  ...            NaN
# 5136          True           Catch Weight             1  ...       1.157895
# 5137         False            Open Weight             1  ...            NaN
# 5138         False            Open Weight             1  ...       0.571429
# 5139         False            Open Weight             1  ...      10.600000
# 5140         False            Open Weight             1  ...            NaN
# 5141         False            Open Weight             1  ...            NaN
# 5142         False            Open Weight             1  ...            NaN
# 5143         False            Open Weight             1  ...            NaN
#
#       Total_Str_Landed  R_odds  B_odds                location_y  country  \
# 0             0.341534   145.0  -165.0    Chicago, Illinois, USA      USA
# 1             0.676667 -1100.0   700.0    Chicago, Illinois, USA      USA
# 2             0.828839  -210.0   175.0    Chicago, Illinois, USA      USA
# 3             1.709360   300.0  -360.0    Chicago, Illinois, USA      USA
# 4             1.893130  -160.0   140.0    Chicago, Illinois, USA      USA
# 5             1.188406  -750.0   525.0    Chicago, Illinois, USA      USA
# 6             0.553936  -160.0   140.0    Chicago, Illinois, USA      USA
# 7             0.921053   105.0  -125.0    Chicago, Illinois, USA      USA
# 8             1.355283   155.0  -175.0    Chicago, Illinois, USA      USA
# 9             0.787156  -220.0   180.0    Chicago, Illinois, USA      USA
# 10            0.421150  -170.0   150.0    Chicago, Illinois, USA      USA
# 11                 NaN  -155.0   135.0    Chicago, Illinois, USA      USA
# 12            1.303977  -105.0  -115.0    Chicago, Illinois, USA      USA
# 13            0.621062  -320.0   260.0         Stockholm, Sweden   Sweden
# 14            4.048611   215.0  -255.0         Stockholm, Sweden   Sweden
# 15            0.786290  -130.0   110.0         Stockholm, Sweden   Sweden
# 16            0.701681  -165.0   145.0         Stockholm, Sweden   Sweden
# 17                 NaN   110.0  -130.0         Stockholm, Sweden   Sweden
# 18                 NaN   135.0  -155.0         Stockholm, Sweden   Sweden
# 19            2.546939  -400.0   325.0         Stockholm, Sweden   Sweden
# 20            0.683505   135.0  -155.0         Stockholm, Sweden   Sweden
# 21            2.847826   110.0  -130.0         Stockholm, Sweden   Sweden
# 22                 NaN  -125.0   105.0         Stockholm, Sweden   Sweden
# 23            9.740741  -110.0  -110.0         Stockholm, Sweden   Sweden
# 24                 NaN  -105.0  -115.0         Stockholm, Sweden   Sweden
# 25            1.072035   130.0  -150.0  Rochester, New York, USA      USA
# 26            2.109375  -160.0   140.0  Rochester, New York, USA      USA
# 27                 NaN  -220.0   180.0  Rochester, New York, USA      USA
# 28                 NaN -1100.0   700.0  Rochester, New York, USA      USA
# 29            2.590209  -420.0   335.0  Rochester, New York, USA      USA
# ...                ...     ...     ...                       ...      ...
# 5114               NaN     NaN     NaN                       NaN      NaN
# 5115               NaN     NaN     NaN                       NaN      NaN
# 5116               NaN     NaN     NaN                       NaN      NaN
# 5117               NaN     NaN     NaN                       NaN      NaN
# 5118               NaN     NaN     NaN                       NaN      NaN
# 5119               NaN     NaN     NaN                       NaN      NaN
# 5120               NaN     NaN     NaN                       NaN      NaN
# 5121          0.476744     NaN     NaN                       NaN      NaN
# 5122          0.523256     NaN     NaN                       NaN      NaN
# 5123          3.958333     NaN     NaN                       NaN      NaN
# 5124          0.356589     NaN     NaN                       NaN      NaN
# 5125          0.550000     NaN     NaN                       NaN      NaN
# 5126               NaN     NaN     NaN                       NaN      NaN
# 5127          0.235294     NaN     NaN                       NaN      NaN
# 5128               NaN     NaN     NaN                       NaN      NaN
# 5129               NaN     NaN     NaN                       NaN      NaN
# 5130               NaN     NaN     NaN                       NaN      NaN
# 5131               NaN     NaN     NaN                       NaN      NaN
# 5132               NaN     NaN     NaN                       NaN      NaN
# 5133               NaN     NaN     NaN                       NaN      NaN
# 5134               NaN     NaN     NaN                       NaN      NaN
# 5135               NaN     NaN     NaN                       NaN      NaN
# 5136          0.875000     NaN     NaN                       NaN      NaN
# 5137               NaN     NaN     NaN                       NaN      NaN
# 5138          1.000000     NaN     NaN                       NaN      NaN
# 5139         12.666667     NaN     NaN                       NaN      NaN
# 5140               NaN     NaN     NaN                       NaN      NaN
# 5141               NaN     NaN     NaN                       NaN      NaN
# 5142               NaN     NaN     NaN                       NaN      NaN
# 5143               NaN     NaN     NaN                       NaN      NaN
#
#       Winner_y  title_bout_y  gender  Year
# 0          Red          True    MALE    19
# 1          Red          True  FEMALE    19
# 2          Red         False    MALE    19
# 3         Blue         False    MALE    19
# 4         Blue         False    MALE    19
# 5          Red         False  FEMALE    19
# 6          Red         False    MALE    19
# 7         Blue         False  FEMALE    19
# 8         Blue         False    MALE    19
# 9          Red         False  FEMALE    19
# 10        Blue         False    MALE    19
# 11         Red         False    MALE    19
# 12         Red         False  FEMALE    19
# 13        Blue         False    MALE    19
# 14        Blue         False    MALE    19
# 15         Red         False    MALE    19
# 16        Blue         False    MALE    19
# 17         Red         False    MALE    19
# 18        Blue         False    MALE    19
# 19        Blue         False  FEMALE    19
# 20        Blue         False    MALE    19
# 21        Blue         False    MALE    19
# 22         Red         False  FEMALE    19
# 23        Blue         False    MALE    19
# 24         Red         False    MALE    19
# 25         Red         False    MALE    19
# 26        Blue         False    MALE    19
# 27        Blue         False  FEMALE    19
# 28         Red         False    MALE    19
# 29         Red         False    MALE    19
# ...        ...           ...     ...   ...
# 5114       NaN           NaN     NaN    94
# 5115       NaN           NaN     NaN    94
# 5116       NaN           NaN     NaN    94
# 5117       NaN           NaN     NaN    94
# 5118       NaN           NaN     NaN    94
# 5119       NaN           NaN     NaN    94
# 5120       NaN           NaN     NaN    94
# 5121       NaN           NaN     NaN    94
# 5122       NaN           NaN     NaN    94
# 5123       NaN           NaN     NaN    94
# 5124       NaN           NaN     NaN    94
# 5125       NaN           NaN     NaN    94
# 5126       NaN           NaN     NaN    94
# 5127       NaN           NaN     NaN    94
# 5128       NaN           NaN     NaN    94
# 5129       NaN           NaN     NaN    94
# 5130       NaN           NaN     NaN    94
# 5131       NaN           NaN     NaN    94
# 5132       NaN           NaN     NaN    94
# 5133       NaN           NaN     NaN    94
# 5134       NaN           NaN     NaN    94
# 5135       NaN           NaN     NaN    94
# 5136       NaN           NaN     NaN    93
# 5137       NaN           NaN     NaN    93
# 5138       NaN           NaN     NaN    93
# 5139       NaN           NaN     NaN    93
# 5140       NaN           NaN     NaN    93
# 5141       NaN           NaN     NaN    93
# 5142       NaN           NaN     NaN    93
# 5143       NaN           NaN     NaN    93
#
# [5144 rows x 178 columns]

# %%
#Seperates the DataFrame into the portion of data containing numbers and the portion containing string values
# This is necessary as the mean function will give an error if there are any stings
df_num = df.select_dtypes(include=[np.number])
df_string = df.select_dtypes(exclude=[np.number])
df_num.shape, df_string.shape
# Out:
# ((5144, 162), (5144, 15))

# %%
df_string.isnull().values.any(), df_num.isnull().values.any()
# Out:
# (True, True)

# %%
#Replaces any String NaNs as 0 and any number NaNs as the average value of the column. 
df_string = df_string.fillna(0)
df_num = df_num.fillna(df_num.median())
df_string.isnull().values.any(), df_num.isnull().values.any()
# Out:
# (False, False)

# %%
#Merge data back into a single data frame.  I think the indexing should be the same so no issues
df = df_num.join(df_string)
df.shape, df.isnull().values.any()
# Out:
# ((5144, 177), False)

# %%
''' 

This may not be necessary.  simpler to do it the other way.  

## This turns the number portions of the data into an array and simple imputer fills NaNs with the average value of the column
## The 1:162 would be the index, howver this appears to work 

# To calculate mean use imputer class
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', verbose=0)
NumData = df_num.iloc[:, :-1].values
imputer = imputer.fit(NumData[:, 1:162])
NumData[:, 1:162] = imputer.transform(NumData[:, 1:162])

## NumData array will need to be coverted back to a datframe and merged with the string information.
## After converting numpy array back into dataframe, merge it with string data.  

'''
# Out:
# " \n\nThis may not be necessary.  simpler to do it the other way.  \n\n## This turns the number portions of the data into an array and simple imputer fills NaNs with the average value of the column\n## The 1:162 would be the index, howver this appears to work \n\n# To calculate mean use imputer class\nfrom sklearn.impute import SimpleImputer\nimputer = SimpleImputer(missing_values=np.nan, strategy='mean', verbose=0)\nNumData = df_num.iloc[:, :-1].values\nimputer = imputer.fit(NumData[:, 1:162])\nNumData[:, 1:162] = imputer.transform(NumData[:, 1:162])\n\n## NumData array will need to be coverted back to a datframe and merged with the string information.\n## After converting numpy array back into dataframe, merge it with string data.  \n\n"

# %%
#df_num_noNAN = pd.DataFrame(NumData, index=df_num.index)

# %%
# make sure no missing values
df.isnull().values.any()
# Out:
# False

# %%
# Drop and replace any erroneous values (e.g. NaN/Infinity)
#df = df.replace([np.inf, -np.inf], np.nan)
#df = df.dropna()
#print(df)

# %%
# Examine the number of fights for each weight class
df_agg = df.groupby(["weight_class"])['B_avg_SIG_STR_pct'].count()
print(df_agg)
# Out:
# weight_class
# Bantamweight             379
# Catch Weight              38
# Featherweight            442
# Flyweight                187
# Heavyweight              507
# Light Heavyweight        502
# Lightweight              989
# Middleweight             725
# Open Weight               92
# Welterweight             969
# Women's Bantamweight     111
# Women's Featherweight     10
# Women's Flyweight         50
# Women's Strawweight      143
# Name: B_avg_SIG_STR_pct, dtype: int64

# %%
#Import python package
from sklearn.model_selection import train_test_split

# Choose one of the following weight classes to subset the UFC dataset
# Looking at Welterweight as it has the highest volume of data out of the weight classes
df_sub = df[(df["weight_class"] == "Lightweight") | 
            (df["weight_class"] == "Middleweight") | 
            (df["weight_class"] == "Welterweight") | 
            (df["weight_class"] == "Flyweight") | 
            (df["weight_class"] == "Bantamweight") |
            (df["weight_class"] == "Light Heavyweight") |
            (df["weight_class"] == "Featherweight")]
#df_sub = df[(df["weight_class"] == "Lightweight")]
# df_sub = df[(df["weight_class"] == "Featherweight")]
# df_sub= df[(df["weight_class"] == "Welterweight")]

# Set the data and target variables
data = df_sub[["B_current_lose_streak",
               "B_current_win_streak",
               "B_avg_BODY_att","B_avg_BODY_landed",
               "B_avg_CLINCH_att",
               "B_avg_CLINCH_landed",
               "B_avg_DISTANCE_att",
               "B_avg_DISTANCE_landed",
               "B_avg_GROUND_att",
               "B_avg_GROUND_landed",
               "B_avg_HEAD_att",
               "B_avg_HEAD_landed",
               "B_avg_KD",
               "B_avg_LEG_att",
               "B_avg_LEG_landed",
               "B_avg_PASS",
               "B_avg_REV",
               "B_avg_SIG_STR_att",
               "B_avg_SIG_STR_landed",
               "B_avg_SIG_STR_pct",
               "B_avg_SUB_ATT",
               "B_avg_TD_att",
               "B_avg_TD_landed","B_avg_TD_pct","B_avg_TOTAL_STR_att","B_avg_TOTAL_STR_landed","B_longest_win_streak",
               "B_losses","B_avg_opp_BODY_att","B_avg_opp_BODY_landed","B_avg_opp_CLINCH_att","B_avg_opp_CLINCH_landed",
               "B_avg_opp_DISTANCE_att","B_avg_opp_DISTANCE_landed","B_avg_opp_GROUND_att","B_avg_opp_GROUND_landed",
               "B_avg_opp_HEAD_att","B_avg_opp_HEAD_landed","B_avg_opp_KD","B_avg_opp_LEG_att","B_avg_opp_LEG_landed",
               "B_avg_opp_PASS","B_avg_opp_REV","B_avg_opp_SIG_STR_att","B_avg_opp_SIG_STR_landed","B_avg_opp_SIG_STR_pct",
               "B_avg_opp_SUB_ATT","B_avg_opp_TD_att","B_avg_opp_TD_landed","B_avg_opp_TD_pct","B_avg_opp_TOTAL_STR_att",
               "B_avg_opp_TOTAL_STR_landed","B_total_rounds_fought","B_total_time_fought(seconds)","B_total_title_bouts",
               "B_win_by_Decision_Majority","B_win_by_Decision_Split","B_win_by_Decision_Unanimous","B_win_by_KO/TKO",
               "B_win_by_Submission","B_win_by_TKO_Doctor_Stoppage","B_wins","R_current_lose_streak","R_current_win_streak",
               "R_avg_BODY_att","R_avg_BODY_landed","R_avg_CLINCH_att","R_avg_CLINCH_landed","R_avg_DISTANCE_att",
               "R_avg_DISTANCE_landed","R_avg_GROUND_att","R_avg_GROUND_landed","R_avg_HEAD_att","R_avg_HEAD_landed",
               "R_avg_KD","R_avg_LEG_att","R_avg_LEG_landed","R_avg_PASS","R_avg_REV","R_avg_SIG_STR_att",
               "R_avg_SIG_STR_landed","R_avg_SIG_STR_pct","R_avg_SUB_ATT","R_avg_TD_att","R_avg_TD_landed","R_avg_TD_pct",
               "R_avg_TOTAL_STR_att","R_avg_TOTAL_STR_landed","R_longest_win_streak","R_losses","R_avg_opp_BODY_att",
               "R_avg_opp_BODY_landed","R_avg_opp_CLINCH_att","R_avg_opp_CLINCH_landed","R_avg_opp_DISTANCE_att",
               "R_avg_opp_DISTANCE_landed","R_avg_opp_GROUND_att","R_avg_opp_GROUND_landed","R_avg_opp_HEAD_att",
               "R_avg_opp_HEAD_landed","R_avg_opp_KD","R_avg_opp_LEG_att","R_avg_opp_LEG_landed","R_avg_opp_PASS",
               "R_avg_opp_REV","R_avg_opp_SIG_STR_att","R_avg_opp_SIG_STR_landed","R_avg_opp_SIG_STR_pct","R_avg_opp_SUB_ATT",
               "R_avg_opp_TD_att","R_avg_opp_TD_landed","R_avg_opp_TD_pct","R_avg_opp_TOTAL_STR_att",
               "R_avg_opp_TOTAL_STR_landed","R_total_rounds_fought","R_total_time_fought(seconds)","R_total_title_bouts",
               "R_win_by_Decision_Majority","R_win_by_Decision_Split","R_win_by_Decision_Unanimous","R_win_by_KO/TKO",
               "R_win_by_Submission","R_win_by_TKO_Doctor_Stoppage","R_wins","R_odds", "B_odds"]]

df_columns = data.columns.values.tolist()
target = df_sub["WinnerNum"]

# Convert the 'data' and target dataframes into numpy arrays. 
# This is the required format for KFold cross validation
data_numpy = data.to_numpy()
target_numpy = target.to_numpy()

# %%
print(data)
# Out:
#       B_current_lose_streak  B_current_win_streak  B_avg_BODY_att  \
# 0                         0                     4        9.200000
# 2                         0                     3       15.354839
# 3                         0                     4       17.000000
# 6                         0                     3       15.000000
# 8                         0                     1        7.250000
# 10                        1                     0        5.428571
# 11                        0                     0        7.000000
# 13                        1                     0        9.272727
# 14                        0                     3       10.333333
# 15                        0                     1        2.500000
# 16                        0                     1        7.000000
# 17                        0                     0        7.000000
# 18                        0                     0        7.000000
# 20                        0                     4        9.666667
# 21                        2                     0       21.666667
# 23                        1                     0        9.500000
# 24                        0                     0        7.000000
# 25                        1                     0       12.714286
# 26                        0                     1       10.000000
# 28                        0                     0        7.000000
# 29                        0                     2       13.181818
# 30                        0                     0        7.000000
# 32                        0                     0        7.000000
# 33                        0                     0        7.000000
# 34                        0                     1        5.000000
# 35                        3                     0        9.666667
# 36                        0                     2        7.000000
# 37                        3                     0       15.750000
# 39                        1                     0        8.652174
# 40                        0                     6       11.833333
# ...                     ...                   ...             ...
# 4976                      1                     0        6.000000
# 4977                      0                     0        7.000000
# 4978                      0                     0        7.000000
# 4979                      0                     0        7.000000
# 4980                      0                     0        7.000000
# 4982                      0                     1       19.000000
# 4984                      1                     0        1.000000
# 4985                      0                     0        7.000000
# 4987                      0                     1        0.000000
# 4990                      0                     0        7.000000
# 4991                      0                     0        7.000000
# 4992                      0                     0        7.000000
# 4993                      0                     0        7.000000
# 4995                      0                     0        7.000000
# 4996                      1                     0        0.666667
# 4997                      0                     0        7.000000
# 4998                      0                     0        7.000000
# 5002                      0                     2        0.500000
# 5015                      0                     1        1.000000
# 5018                      0                     0        7.000000
# 5019                      0                     0        7.000000
# 5021                      0                     0        7.000000
# 5024                      0                     1        1.000000
# 5027                      0                     0        7.000000
# 5028                      1                     0        0.000000
# 5029                      0                     0        7.000000
# 5030                      0                     0        7.000000
# 5033                      0                     0        7.000000
# 5036                      0                     0        7.000000
# 5037                      0                     0        7.000000
#
#       B_avg_BODY_landed  B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# 0              6.000000          0.200000             0.000000
# 2             11.322581          6.741935             4.387097
# 3             14.000000         13.750000            11.000000
# 6              7.416667          6.083333             3.416667
# 8              4.750000          1.750000             0.500000
# 10             4.142857         12.285714             9.142857
# 11             5.000000          6.333333             4.200000
# 13             6.181818          6.818182             5.272727
# 14             8.333333          6.666667             4.666667
# 15             1.000000          5.000000             2.500000
# 16             4.200000          4.600000             2.600000
# 17             5.000000          6.333333             4.200000
# 18             5.000000          6.333333             4.200000
# 20             5.166667          2.000000             1.000000
# 21            17.666667         13.333333            10.333333
# 23             7.166667         12.166667             9.000000
# 24             5.000000          6.333333             4.200000
# 25             9.714286          6.142857             4.714286
# 26            10.000000         21.000000            14.000000
# 28             5.000000          6.333333             4.200000
# 29            10.590909         13.227273             8.863636
# 30             5.000000          6.333333             4.200000
# 32             5.000000          6.333333             4.200000
# 33             5.000000          6.333333             4.200000
# 34             2.000000         12.000000             5.000000
# 35             7.952381         10.952381             7.857143
# 36             6.000000          2.500000             2.500000
# 37            11.750000         11.250000             8.000000
# 39             6.956522          6.217391             5.217391
# 40             8.833333         14.833333            10.500000
# ...                 ...               ...                  ...
# 4976           5.000000          7.000000             6.000000
# 4977           5.000000          6.333333             4.200000
# 4978           5.000000          6.333333             4.200000
# 4979           5.000000          6.333333             4.200000
# 4980           5.000000          6.333333             4.200000
# 4982          17.000000         23.000000            10.000000
# 4984           1.000000          0.000000             0.000000
# 4985           5.000000          6.333333             4.200000
# 4987           0.000000          0.000000             0.000000
# 4990           5.000000          6.333333             4.200000
# 4991           5.000000          6.333333             4.200000
# 4992           5.000000          6.333333             4.200000
# 4993           5.000000          6.333333             4.200000
# 4995           5.000000          6.333333             4.200000
# 4996           0.333333          0.333333             0.000000
# 4997           5.000000          6.333333             4.200000
# 4998           5.000000          6.333333             4.200000
# 5002           0.000000          0.500000             0.000000
# 5015           1.000000          0.000000             0.000000
# 5018           5.000000          6.333333             4.200000
# 5019           5.000000          6.333333             4.200000
# 5021           5.000000          6.333333             4.200000
# 5024           1.000000          0.000000             0.000000
# 5027           5.000000          6.333333             4.200000
# 5028           0.000000          0.000000             0.000000
# 5029           5.000000          6.333333             4.200000
# 5030           5.000000          6.333333             4.200000
# 5033           5.000000          6.333333             4.200000
# 5036           5.000000          6.333333             4.200000
# 5037           5.000000          6.333333             4.200000
#
#       B_avg_DISTANCE_att  B_avg_DISTANCE_landed  B_avg_GROUND_att  \
# 0              62.600000              20.600000          2.600000
# 2              84.741935              38.580645          5.516129
# 3             109.500000              48.750000         13.000000
# 6              84.916667              34.666667          5.083333
# 8             125.000000              50.750000          8.750000
# 10             37.857143              11.714286          5.142857
# 11             44.666667              15.200000          6.500000
# 13             57.181818              25.909091          2.636364
# 14             68.333333              26.333333         38.000000
# 15             45.500000              13.500000          3.000000
# 16             42.800000              11.000000         12.800000
# 17             44.666667              15.200000          6.500000
# 18             44.666667              15.200000          6.500000
# 20             53.833333              18.833333          6.500000
# 21            177.333333              84.000000          2.333333
# 23             37.166667              16.333333         11.666667
# 24             44.666667              15.200000          6.500000
# 25             83.214286              26.000000         24.285714
# 26             59.000000              30.000000         15.000000
# 28             44.666667              15.200000          6.500000
# 29             62.045455              25.545455         11.954545
# 30             44.666667              15.200000          6.500000
# 32             44.666667              15.200000          6.500000
# 33             44.666667              15.200000          6.500000
# 34             75.000000              28.000000         41.000000
# 35             36.142857              13.142857         12.571429
# 36             62.000000              38.000000         18.500000
# 37             45.000000              21.000000          4.750000
# 39             41.739130              22.130435          7.913043
# 40             68.500000              36.500000         36.166667
# ...                  ...                    ...               ...
# 4976            2.000000               0.000000         25.000000
# 4977           44.666667              15.200000          6.500000
# 4978           44.666667              15.200000          6.500000
# 4979           44.666667              15.200000          6.500000
# 4980           44.666667              15.200000          6.500000
# 4982           35.000000              12.000000         22.000000
# 4984           13.000000               4.000000         12.000000
# 4985           44.666667              15.200000          6.500000
# 4987            0.000000               0.000000          1.000000
# 4990           44.666667              15.200000          6.500000
# 4991           44.666667              15.200000          6.500000
# 4992           44.666667              15.200000          6.500000
# 4993           44.666667              15.200000          6.500000
# 4995           44.666667              15.200000          6.500000
# 4996            1.666667               0.666667          2.333333
# 4997           44.666667              15.200000          6.500000
# 4998           44.666667              15.200000          6.500000
# 5002            1.000000               0.000000          3.500000
# 5015            0.000000               0.000000          8.000000
# 5018           44.666667              15.200000          6.500000
# 5019           44.666667              15.200000          6.500000
# 5021           44.666667              15.200000          6.500000
# 5024            1.000000               1.000000         23.000000
# 5027           44.666667              15.200000          6.500000
# 5028            2.000000               1.000000          0.000000
# 5029           44.666667              15.200000          6.500000
# 5030           44.666667              15.200000          6.500000
# 5033           44.666667              15.200000          6.500000
# 5036           44.666667              15.200000          6.500000
# 5037           44.666667              15.200000          6.500000
#
#       B_avg_GROUND_landed  ...  R_total_title_bouts  \
# 0                2.000000  ...                    3
# 2                3.806452  ...                    2
# 3               10.500000  ...                    0
# 6                3.416667  ...                    0
# 8                5.000000  ...                    1
# 10               3.285714  ...                    0
# 11               4.333333  ...                    1
# 13               2.000000  ...                    3
# 14              29.333333  ...                    0
# 15               1.000000  ...                    0
# 16               6.200000  ...                    0
# 17               4.333333  ...                    0
# 18               4.333333  ...                    0
# 20               5.333333  ...                    0
# 21               0.666667  ...                    0
# 23              10.166667  ...                    0
# 24               4.333333  ...                    0
# 25              18.357143  ...                    4
# 26              11.000000  ...                    1
# 28               4.333333  ...                    0
# 29               9.500000  ...                    0
# 30               4.333333  ...                    0
# 32               4.333333  ...                    0
# 33               4.333333  ...                    0
# 34              24.000000  ...                    1
# 35               8.714286  ...                    0
# 36              15.000000  ...                    0
# 37               3.500000  ...                    0
# 39               6.173913  ...                    0
# 40              25.000000  ...                   11
# ...                   ...  ...                  ...
# 4976             7.000000  ...                    1
# 4977             4.333333  ...                    0
# 4978             4.333333  ...                    0
# 4979             4.333333  ...                    3
# 4980             4.333333  ...                    1
# 4982            20.000000  ...                    1
# 4984            10.000000  ...                    0
# 4985             4.333333  ...                    2
# 4987             1.000000  ...                    0
# 4990             4.333333  ...                    0
# 4991             4.333333  ...                    0
# 4992             4.333333  ...                    0
# 4993             4.333333  ...                    1
# 4995             4.333333  ...                    0
# 4996             1.666667  ...                    1
# 4997             4.333333  ...                    0
# 4998             4.333333  ...                    0
# 5002             2.500000  ...                    0
# 5015             5.000000  ...                    0
# 5018             4.333333  ...                    0
# 5019             4.333333  ...                    0
# 5021             4.333333  ...                    0
# 5024            20.000000  ...                    0
# 5027             4.333333  ...                    0
# 5028             0.000000  ...                    0
# 5029             4.333333  ...                    0
# 5030             4.333333  ...                    0
# 5033             4.333333  ...                    0
# 5036             4.333333  ...                    0
# 5037             4.333333  ...                    0
#
#       R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# 0                              0                        2
# 2                              0                        1
# 3                              0                        1
# 6                              0                        0
# 8                              0                        0
# 10                             0                        0
# 11                             0                        1
# 13                             0                        0
# 14                             0                        0
# 15                             0                        1
# 16                             0                        1
# 17                             0                        0
# 18                             0                        0
# 20                             1                        1
# 21                             0                        0
# 23                             0                        0
# 24                             0                        0
# 25                             0                        0
# 26                             0                        0
# 28                             0                        0
# 29                             0                        0
# 30                             0                        0
# 32                             0                        1
# 33                             0                        1
# 34                             0                        2
# 35                             0                        1
# 36                             0                        0
# 37                             0                        0
# 39                             0                        0
# 40                             0                        0
# ...                          ...                      ...
# 4976                           0                        0
# 4977                           0                        0
# 4978                           0                        0
# 4979                           0                        0
# 4980                           0                        0
# 4982                           0                        1
# 4984                           0                        0
# 4985                           0                        0
# 4987                           0                        0
# 4990                           0                        0
# 4991                           0                        0
# 4992                           0                        0
# 4993                           0                        0
# 4995                           0                        1
# 4996                           0                        0
# 4997                           0                        0
# 4998                           0                        0
# 5002                           0                        0
# 5015                           0                        0
# 5018                           0                        0
# 5019                           0                        0
# 5021                           0                        0
# 5024                           0                        0
# 5027                           0                        0
# 5028                           0                        0
# 5029                           0                        0
# 5030                           0                        0
# 5033                           0                        0
# 5036                           0                        0
# 5037                           0                        0
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                               4                2                    0
# 2                               3                3                    6
# 3                               4                1                    0
# 6                               5                1                    3
# 8                               3                4                    3
# 10                              0                0                    0
# 11                              0                4                    0
# 13                              3                5                    2
# 14                              1                3                    0
# 15                              1                1                    1
# 16                              0                2                    0
# 17                              0                0                    0
# 18                              0                0                    0
# 20                              2                2                    0
# 21                              4                0                    0
# 23                              0                1                    0
# 24                              0                0                    0
# 25                             10                4                    3
# 26                              2                0                    4
# 28                              0                5                    3
# 29                              1                0                   13
# 30                              0                0                    3
# 32                              1                1                    0
# 33                              1                2                    1
# 34                              0                0                    0
# 35                              3                2                    0
# 36                              3                1                    3
# 37                              1                0                    1
# 39                              1                3                    0
# 40                              6                4                    0
# ...                           ...              ...                  ...
# 4976                            0                1                    0
# 4977                            0                0                    0
# 4978                            0                0                    0
# 4979                            0                1                    2
# 4980                            0                3                    1
# 4982                            0                0                    1
# 4984                            0                0                    0
# 4985                            0                1                    1
# 4987                            1                0                    0
# 4990                            0                0                    0
# 4991                            0                0                    0
# 4992                            0                0                    0
# 4993                            0                0                    1
# 4995                            0                0                    0
# 4996                            1                0                    3
# 4997                            0                0                    0
# 4998                            0                0                    0
# 5002                            0                0                    0
# 5015                            0                1                    0
# 5018                            0                0                    0
# 5019                            0                0                    0
# 5021                            0                0                    0
# 5024                            1                1                    0
# 5027                            0                0                    0
# 5028                            0                1                    0
# 5029                            0                0                    0
# 5030                            0                0                    0
# 5033                            1                0                    2
# 5036                            0                0                    0
# 5037                            1                0                    1
#
#       R_win_by_TKO_Doctor_Stoppage  R_wins  R_odds  B_odds
# 0                                0       8   145.0  -165.0
# 2                                1      14  -210.0   175.0
# 3                                0       6   300.0  -360.0
# 6                                0       9  -160.0   140.0
# 8                                0      10   155.0  -175.0
# 10                               0       0  -170.0   150.0
# 11                               0       5  -155.0   135.0
# 13                               0      10  -320.0   260.0
# 14                               2       6   215.0  -255.0
# 15                               0       4  -130.0   110.0
# 16                               0       3  -165.0   145.0
# 17                               0       0   110.0  -130.0
# 18                               0       0   135.0  -155.0
# 20                               0       6   135.0  -155.0
# 21                               0       4   110.0  -130.0
# 23                               0       1  -110.0  -110.0
# 24                               0       0  -105.0  -115.0
# 25                               0      17   130.0  -150.0
# 26                               0       6  -160.0   140.0
# 28                               0       8 -1100.0   700.0
# 29                               0      14  -420.0   335.0
# 30                               0       3  -550.0   425.0
# 32                               0       3  -900.0   600.0
# 33                               0       5  -250.0   210.0
# 34                               0       2   145.0  -165.0
# 35                               0       6  -260.0   220.0
# 36                               0       7   170.0  -200.0
# 37                               0       2  -800.0   550.0
# 39                               0       4  -135.0   115.0
# 40                               0      10  -145.0   125.0
# ...                            ...     ...     ...     ...
# 4976                             0       1  -150.0   135.0
# 4977                             0       0  -150.0   135.0
# 4978                             0       0  -150.0   135.0
# 4979                             0       3  -150.0   135.0
# 4980                             0       4  -150.0   135.0
# 4982                             0       2  -150.0   135.0
# 4984                             0       0  -150.0   135.0
# 4985                             0       2  -150.0   135.0
# 4987                             0       1  -150.0   135.0
# 4990                             0       0  -150.0   135.0
# 4991                             0       0  -150.0   135.0
# 4992                             0       0  -150.0   135.0
# 4993                             0       1  -150.0   135.0
# 4995                             0       1  -150.0   135.0
# 4996                             0       4  -150.0   135.0
# 4997                             0       0  -150.0   135.0
# 4998                             0       0  -150.0   135.0
# 5002                             0       0  -150.0   135.0
# 5015                             0       1  -150.0   135.0
# 5018                             0       0  -150.0   135.0
# 5019                             0       0  -150.0   135.0
# 5021                             0       0  -150.0   135.0
# 5024                             0       2  -150.0   135.0
# 5027                             0       0  -150.0   135.0
# 5028                             0       1  -150.0   135.0
# 5029                             0       0  -150.0   135.0
# 5030                             0       0  -150.0   135.0
# 5033                             0       3  -150.0   135.0
# 5036                             0       0  -150.0   135.0
# 5037                             0       2  -150.0   135.0
#
# [4193 rows x 126 columns]

# %%
# Import python package
from sklearn.preprocessing import RobustScaler

# Scale UFC fight data using 'robust' scaler
# Currently, the robust scaler is scaling the ENTIRE dataset.
# Additional work is needed to apply the robust scaler to individual columns of the dataset
robust = RobustScaler()
data_numpy_robust = robust.fit_transform(data_numpy)


# Import python package
from sklearn.preprocessing import StandardScaler

# Unfinished - This needs more work
scaler = StandardScaler()
data_numpy_standard_scaler = scaler.fit_transform(data_numpy)

# Import python package
from sklearn.preprocessing import MinMaxScaler

# Unfinished - This needs more work
minmax = MinMaxScaler()
data_numpy_minmax = minmax.fit_transform(data_numpy)


# Import python package
from sklearn.preprocessing import Normalizer

# Unfinished - This needs more work
norm = Normalizer()
data_numpy_norm = norm.fit_transform(data_numpy)

# %%
# Import python packages
''' 
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn import metrics

# Parameterize the number of KFolds. For now, set the number of folds equal to 10
rkf = RepeatedKFold(n_splits=10, n_repeats=100, random_state=1234)

# This splits the data into the number of specified folds
rkf.get_n_splits(data_numpy)

# Set up a blank list and DataFrame, for which we will append accuracy scores 
# in the subsequent For-Loop
accuracy = []
all_scores = pd.DataFrame()

# Create For-Loop to loop through the cross folds of the data-set
for train_index, test_index in rkf.split(data_numpy):
    X_train, X_test = data_numpy[train_index], data_numpy[test_index]
    y_train, y_test = target_numpy[train_index], target_numpy[test_index]

    # Choose the preferred classifier and associated parameters (e.g. max_iter, C, etc.)
    # Currently only 3 are loaded, LinearSVC, LogReg, and Ridge--we can add others
    # clf = LinearSVC(max_iter=1000, C = 100)
    #clf = LogisticRegression(solver = "lbfgs", C = 10, max_iter = 1000)
    clf = RidgeClassifier(normalize = True)
    clf.fit(X_train,y_train) # Fit the classifer based on X_train, and y_train 
    y_pred=clf.predict(X_test) # Make predictions based on X_test set
    score = metrics.accuracy_score(y_test, y_pred) # Determine the Model accuracy 
    accuracy.append(score) # Append the accuracy scores to the 'accuracy' list
all_scores["Folds"] = accuracy # Port the accuracy scores into the all_scores DataFrame
'''

# %%
# Import python packages
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn import metrics

# Set up a blank list and DataFrame, for which we will append accuracy scores 
# in the subsequent For-Loop
accuracy = []
all_scores = pd.DataFrame()

# Create For-Loop to loop through the cross folds of the data-set
X_train_data = data[~data['Year' == '2019']] 
X_test_data = data[~data['Year' == '2019']] 
y_train_data = target[~target['Year' == '2019']] 
y_test_data = target[target['Year' == '2019']] 


    X_train = X_train_data.to_numpy()
    X_test = X_test_data.to_numpy()
    y_train = y_train_data.to_numpy()
    y_test = y_test_data.to_numpy()

    # Choose the preferred classifier and associated parameters (e.g. max_iter, C, etc.)
    # Currently only 3 are loaded, LinearSVC, LogReg, and Ridge--we can add others
    # clf = LinearSVC(max_iter=1000, C = 100)
    #clf = LogisticRegression(solver = "lbfgs", C = 10, max_iter = 1000)
    clf = RidgeClassifier(normalize = True)
    clf.fit(X_train,y_train) # Fit the classifer based on X_train, and y_train 
    y_pred=clf.predict(X_test) # Make predictions based on X_test set
    score = metrics.accuracy_score(y_test, y_pred) # Determine the Model accuracy 
    accuracy.append(score) # Append the accuracy scores to the 'accuracy' list
all_scores["Folds"] = accuracy # Port the accuracy scores into the all_scores DataFrame

# %%
# Print the Classifier Accuracies across the KFolds
print(all_scores)
print("Average Accuracy: " + str(all_scores["Folds"].mean()))
# Out:
#         Folds
# 0    0.666667
# 1    0.728571
# 2    0.740476
# 3    0.763723
# 4    0.727924
# 5    0.708831
# 6    0.668258
# 7    0.723150
# 8    0.694511
# 9    0.720764
# 10   0.721429
# 11   0.723810
# 12   0.719048
# 13   0.737470
# 14   0.730310
# 15   0.663484
# 16   0.713604
# 17   0.701671
# 18   0.699284
# 19   0.718377
# 20   0.695238
# 21   0.709524
# 22   0.750000
# 23   0.711217
# 24   0.742243
# 25   0.689737
# 26   0.675418
# 27   0.708831
# 28   0.704057
# 29   0.718377
# ..        ...
# 970  0.723810
# 971  0.711905
# 972  0.688095
# 973  0.711217
# 974  0.675418
# 975  0.737470
# 976  0.761337
# 977  0.732697
# 978  0.689737
# 979  0.653938
# 980  0.702381
# 981  0.735714
# 982  0.735714
# 983  0.682578
# 984  0.675418
# 985  0.701671
# 986  0.737470
# 987  0.732697
# 988  0.687351
# 989  0.706444
# 990  0.685714
# 991  0.716667
# 992  0.704762
# 993  0.711217
# 994  0.735084
# 995  0.732697
# 996  0.708831
# 997  0.687351
# 998  0.715990
# 999  0.680191
#
# [1000 rows x 1 columns]
# Average Accuracy: 0.711300721672917

# %%
# Import Python Modules
import seaborn as sns
import matplotlib.pyplot as plt

# Use Seaborn to Create a histogram of the Accuracies between the KFolds
# %matplotlib inline 
sns.distplot(accuracy)
# Out:
# /Users/gregzaimes/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Create dictionary to map Feature Weights to Feature Metadata
coef_dict = {}
for coef, feat in zip(abs(clf.coef_[0]),df_columns):
    coef_dict[feat] = coef 
    
# Pull out and sort the Feature Weights of the Classifier, in ascending order
feature_weights_sorted = dict(sorted(coef_dict.items(), key=lambda x: x[1], reverse = True))
feature_weights_sorted
# Out:
# {'R_avg_opp_SIG_STR_pct': 0.15128104460467132,
#  'R_avg_TD_pct': 0.09286804752208142,
#  'B_avg_opp_TD_pct': 0.08865784227574271,
#  'B_avg_SIG_STR_pct': 0.08602030519115952,
#  'R_avg_opp_KD': 0.07699842198779898,
#  'B_win_by_TKO_Doctor_Stoppage': 0.06306565471118167,
#  'B_win_by_Decision_Majority': 0.058906008173067605,
#  'R_avg_SIG_STR_pct': 0.04944399598472744,
#  'B_avg_TD_pct': 0.049313905172325326,
#  'R_avg_SUB_ATT': 0.040573909272064765,
#  'R_win_by_Decision_Split': 0.040493312228208,
#  'B_avg_opp_SIG_STR_pct': 0.031886582104034965,
#  'R_avg_REV': 0.02431732308127701,
#  'R_win_by_TKO_Doctor_Stoppage': 0.024097265231270457,
#  'B_total_title_bouts': 0.022266195644203155,
#  'B_avg_opp_KD': 0.019360869013626297,
#  'R_avg_opp_SUB_ATT': 0.01742304001755959,
#  'B_avg_opp_SUB_ATT': 0.01724042345452482,
#  'R_avg_opp_REV': 0.01634987031962885,
#  'B_win_by_Decision_Split': 0.014318766758517216,
#  'B_avg_TD_landed': 0.01411592774828271,
#  'B_avg_SUB_ATT': 0.013896564715904234,
#  'B_avg_opp_TD_landed': 0.013173890414042972,
#  'B_avg_TD_att': 0.012176629745543566,
#  'R_total_title_bouts': 0.010847845536427264,
#  'B_current_win_streak': 0.010838917008590802,
#  'B_win_by_Decision_Unanimous': 0.010309728365032135,
#  'R_losses': 0.009868369067088297,
#  'R_current_lose_streak': 0.009775954172744171,
#  'B_avg_REV': 0.009476331225935037,
#  'R_avg_opp_TD_landed': 0.008419497089963661,
#  'R_win_by_Decision_Majority': 0.007529142012313618,
#  'R_avg_opp_TD_pct': 0.007067606176389523,
#  'R_avg_PASS': 0.006585687357555036,
#  'B_avg_opp_PASS': 0.005968093886848935,
#  'R_avg_TD_landed': 0.005846785003312072,
#  'R_avg_KD': 0.00484805915405352,
#  'B_losses': 0.0046339106734006935,
#  'B_current_lose_streak': 0.004489672839798969,
#  'R_avg_opp_PASS': 0.004458399589252556,
#  'B_avg_KD': 0.004002923460895482,
#  'R_win_by_Decision_Unanimous': 0.003744413686518995,
#  'R_win_by_Submission': 0.003594626606922132,
#  'B_avg_opp_TD_att': 0.0035669621579989563,
#  'R_longest_win_streak': 0.0033068189414804158,
#  'B_avg_opp_LEG_landed': 0.003108732866848234,
#  'B_avg_BODY_att': 0.0030508911311558024,
#  'R_avg_TD_att': 0.002714638030686898,
#  'B_avg_BODY_landed': 0.0026618941925662517,
#  'R_avg_BODY_att': 0.002501240442395744,
#  'R_avg_CLINCH_att': 0.002306201205594639,
#  'R_wins': 0.0022446915986740162,
#  'B_avg_opp_CLINCH_att': 0.0020973089830401137,
#  'R_current_win_streak': 0.0020423514787343616,
#  'R_avg_opp_GROUND_landed': 0.0020360258624306272,
#  'B_avg_opp_BODY_att': 0.0018922204190618755,
#  'B_avg_opp_LEG_att': 0.0017697164480911323,
#  'B_avg_opp_REV': 0.00176345643838764,
#  'B_avg_opp_CLINCH_landed': 0.0017511650944639363,
#  'R_avg_GROUND_att': 0.001673307103149213,
#  'R_avg_opp_CLINCH_landed': 0.0016189733483523568,
#  'R_avg_opp_HEAD_landed': 0.0016144790119631788,
#  'B_avg_opp_GROUND_att': 0.001246705637666978,
#  'R_avg_BODY_landed': 0.001188229565703457,
#  'B_avg_PASS': 0.0011569257932539365,
#  'B_avg_opp_GROUND_landed': 0.0011064978898004019,
#  'R_avg_opp_GROUND_att': 0.0010622842416874252,
#  'B_wins': 0.0010142191558756856,
#  'R_avg_CLINCH_landed': 0.0009059809103985203,
#  'R_total_rounds_fought': 0.0009029653902718247,
#  'R_avg_opp_SIG_STR_landed': 0.0008867543370149704,
#  'R_avg_opp_DISTANCE_landed': 0.0007574395579961539,
#  'B_avg_DISTANCE_landed': 0.0007498326874422721,
#  'B_avg_HEAD_landed': 0.0007466320348069502,
#  'R_avg_opp_TD_att': 0.0007311821456280831,
#  'B_avg_opp_BODY_landed': 0.0007005967179402772,
#  'R_avg_opp_LEG_landed': 0.0006447003749931072,
#  'B_total_rounds_fought': 0.0006298730755835214,
#  'R_avg_opp_BODY_landed': 0.0005834788598859623,
#  'B_avg_CLINCH_att': 0.0005566484546776587,
#  'B_avg_SIG_STR_landed': 0.000544541021097505,
#  'R_avg_opp_BODY_att': 0.0004937598828080711,
#  'B_avg_GROUND_att': 0.00048435263712780767,
#  'B_avg_opp_DISTANCE_landed': 0.0004507804625606194,
#  'B_avg_TOTAL_STR_landed': 0.0004290338975790874,
#  'B_odds': 0.0004238212003015134,
#  'B_longest_win_streak': 0.00042138009674222833,
#  'B_win_by_KO/TKO': 0.00039275826422725856,
#  'R_odds': 0.0003777762878917665,
#  'R_avg_opp_CLINCH_att': 0.00037525995949656545,
#  'B_avg_LEG_landed': 0.0003507822755608864,
#  'B_win_by_Submission': 0.00033908526064339395,
#  'B_avg_DISTANCE_att': 0.00030695575624934616,
#  'R_avg_LEG_att': 0.00030361865114217644,
#  'R_avg_opp_LEG_att': 0.0003024007961074519,
#  'B_avg_opp_TOTAL_STR_landed': 0.0002960362367513355,
#  'R_avg_GROUND_landed': 0.00025151004159940007,
#  'B_avg_SIG_STR_att': 0.00023338647575934295,
#  'B_avg_HEAD_att': 0.0002194049400272428,
#  'B_avg_LEG_att': 0.00020213251282004519,
#  'R_avg_HEAD_landed': 0.00020069551777828352,
#  'R_avg_DISTANCE_att': 0.0001980177147895883,
#  'B_avg_opp_HEAD_att': 0.00019554240477427456,
#  'B_avg_opp_HEAD_landed': 0.0001684539010440039,
#  'R_avg_opp_DISTANCE_att': 0.00014475850993339516,
#  'R_avg_DISTANCE_landed': 0.0001432463428523378,
#  'R_avg_TOTAL_STR_landed': 0.00013522343700865256,
#  'R_avg_opp_TOTAL_STR_landed': 0.00013371681472744654,
#  'B_avg_GROUND_landed': 0.00010932862460375592,
#  'R_avg_opp_HEAD_att': 0.00010860009009576735,
#  'B_avg_opp_TOTAL_STR_att': 8.961069128348311e-05,
#  'B_avg_opp_SIG_STR_landed': 8.793022602882643e-05,
#  'R_avg_HEAD_att': 8.066245730380948e-05,
#  'R_avg_opp_SIG_STR_att': 8.054017398065117e-05,
#  'B_avg_CLINCH_landed': 6.72597884292179e-05,
#  'B_avg_opp_DISTANCE_att': 5.533960412346106e-05,
#  'B_avg_opp_SIG_STR_att': 5.250561365209715e-05,
#  'R_avg_LEG_landed': 5.1125025525653025e-05,
#  'R_win_by_KO/TKO': 4.829526735815782e-05,
#  'B_total_time_fought(seconds)': 3.5340079743496397e-05,
#  'B_avg_TOTAL_STR_att': 2.6105988656524532e-05,
#  'R_avg_opp_TOTAL_STR_att': 2.6088531928074546e-05,
#  'R_avg_SIG_STR_att': 2.3455386814650926e-05,
#  'R_total_time_fought(seconds)': 2.1576169660347672e-05,
#  'R_avg_TOTAL_STR_att': 1.885753039774215e-05,
#  'R_avg_SIG_STR_landed': 3.735774821196803e-06}

# %%
# Top 50 feature weights
list(feature_weights_sorted.keys())[0:50]
# Out:
# ['R_avg_opp_SIG_STR_pct',
#  'R_avg_TD_pct',
#  'B_avg_opp_TD_pct',
#  'B_avg_SIG_STR_pct',
#  'R_avg_opp_KD',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_win_by_Decision_Majority',
#  'R_avg_SIG_STR_pct',
#  'B_avg_TD_pct',
#  'R_avg_SUB_ATT',
#  'R_win_by_Decision_Split',
#  'B_avg_opp_SIG_STR_pct',
#  'R_avg_REV',
#  'R_win_by_TKO_Doctor_Stoppage',
#  'B_total_title_bouts',
#  'B_avg_opp_KD',
#  'R_avg_opp_SUB_ATT',
#  'B_avg_opp_SUB_ATT',
#  'R_avg_opp_REV',
#  'B_win_by_Decision_Split',
#  'B_avg_TD_landed',
#  'B_avg_SUB_ATT',
#  'B_avg_opp_TD_landed',
#  'B_avg_TD_att',
#  'R_total_title_bouts',
#  'B_current_win_streak',
#  'B_win_by_Decision_Unanimous',
#  'R_losses',
#  'R_current_lose_streak',
#  'B_avg_REV',
#  'R_avg_opp_TD_landed',
#  'R_win_by_Decision_Majority',
#  'R_avg_opp_TD_pct',
#  'R_avg_PASS',
#  'B_avg_opp_PASS',
#  'R_avg_TD_landed',
#  'R_avg_KD',
#  'B_losses',
#  'B_current_lose_streak',
#  'R_avg_opp_PASS',
#  'B_avg_KD',
#  'R_win_by_Decision_Unanimous',
#  'R_win_by_Submission',
#  'B_avg_opp_TD_att',
#  'R_longest_win_streak',
#  'B_avg_opp_LEG_landed',
#  'B_avg_BODY_att',
#  'R_avg_TD_att',
#  'B_avg_BODY_landed',
#  'R_avg_BODY_att']
